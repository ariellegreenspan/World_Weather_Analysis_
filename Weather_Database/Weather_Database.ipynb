# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps

# %%
# Create a set of random latitude and longitude combinations.
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.
from citipy import citipy
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Perform an API call with the OpenWeatherMap.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Import datetime
from datetime import datetime

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kahului
# Processing Record 2 of Set 1 | east london
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | namatanai
# Processing Record 10 of Set 1 | chuy
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | danshui
# Processing Record 16 of Set 1 | port elizabeth
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | viedma
# Processing Record 19 of Set 1 | dubbo
# Processing Record 20 of Set 1 | yichang
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | port lincoln
# Processing Record 24 of Set 1 | gigmoto
# Processing Record 25 of Set 1 | tessalit
# Processing Record 26 of Set 1 | upernavik
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 32 of Set 1 | lincolnton
# Processing Record 33 of Set 1 | yeppoon
# Processing Record 34 of Set 1 | inuvik
# Processing Record 35 of Set 1 | phalombe
# Processing Record 36 of Set 1 | peniche
# Processing Record 37 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | ramona
# Processing Record 40 of Set 1 | ushuaia
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 1 | katsuura
# Processing Record 44 of Set 1 | puerto baquerizo moreno
# Processing Record 45 of Set 1 | dyersburg
# Processing Record 46 of Set 1 | megion
# Processing Record 47 of Set 1 | yakima
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | guerrero negro
# Processing Record 2 of Set 2 | alofi
# Processing Record 3 of Set 2 | saint-pierre
# Processing Record 4 of Set 2 | waipawa
# Processing Record 5 of Set 2 | flin flon
# Processing Record 6 of Set 2 | la libertad
# Processing Record 7 of Set 2 | la llave
# Processing Record 8 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 2 | sioux lookout
# Processing Record 10 of Set 2 | new norfolk
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | dikson
# Processing Record 14 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 2 | lakes entrance
# Processing Record 16 of Set 2 | anadyr
# Processing Record 17 of Set 2 | port hedland
# Processing Record 18 of Set 2 | kearney
# Processing Record 19 of Set 2 | esil
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | tiarei
# Processing Record 24 of Set 2 | jizan
# Processing Record 25 of Set 2 | hermanus
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | leningradskiy
# Processing Record 28 of Set 2 | san carlos de bariloche
# Processing Record 29 of Set 2 | bethel
# Processing Record 30 of Set 2 | fray bentos
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | cetraro
# Processing Record 34 of Set 2 | ribeira grande
# Processing Record 35 of Set 2 | punta arenas
# Processing Record 36 of Set 2 | sirur
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | constitucion
# Processing Record 39 of Set 2 | kobryn
# Processing Record 40 of Set 2 | kalcheva
# Processing Record 41 of Set 2 | san patricio
# Processing Record 42 of Set 2 | kungurtug
# Processing Record 43 of Set 2 | buala
# Processing Record 44 of Set 2 | nisia floresta
# Processing Record 45 of Set 2 | maniitsoq
# Processing Record 46 of Set 2 | severo-kurilsk
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | yelizovo
# Processing Record 49 of Set 2 | kashi
# Processing Record 50 of Set 2 | vorobyevka
# Processing Record 1 of Set 3 | khatanga
# Processing Record 2 of Set 3 | awjilah
# Processing Record 3 of Set 3 | klyuchi
# Processing Record 4 of Set 3 | vila
# Processing Record 5 of Set 3 | burnie
# Processing Record 6 of Set 3 | siverek
# Processing Record 7 of Set 3 | tasiilaq
# Processing Record 8 of Set 3 | mackay
# Processing Record 9 of Set 3 | bonavista
# Processing Record 10 of Set 3 | mahon
# Processing Record 11 of Set 3 | cape town
# Processing Record 12 of Set 3 | busselton
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | avarua
# Processing Record 16 of Set 3 | sitka
# Processing Record 17 of Set 3 | kvitok
# Processing Record 18 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | praia da vitoria
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 3 | lingao
# Processing Record 24 of Set 3 | juneau
# Processing Record 25 of Set 3 | sidrolandia
# Processing Record 26 of Set 3 | marzuq
# Processing Record 27 of Set 3 | bowen
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | riyadh
# Processing Record 30 of Set 3 | ambatondrazaka
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | naze
# Processing Record 33 of Set 3 | erenhot
# Processing Record 34 of Set 3 | porosozero
# Processing Record 35 of Set 3 | asfi
# Processing Record 36 of Set 3 | padang
# Processing Record 37 of Set 3 | chokurdakh
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 3 | rafsanjan
# Processing Record 41 of Set 3 | barrow
# Processing Record 42 of Set 3 | roald
# Processing Record 43 of Set 3 | gannan
# Processing Record 44 of Set 3 | george
# Processing Record 45 of Set 3 | ishigaki
# Processing Record 46 of Set 3 | hithadhoo
# Processing Record 47 of Set 3 | dabhol
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | asau
# Processing Record 50 of Set 3 | cidreira
# Processing Record 1 of Set 4 | mount darwin
# Processing Record 2 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 3 of Set 4 | marshall
# Processing Record 4 of Set 4 | kapaa
# Processing Record 5 of Set 4 | saldanha
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 4 | killybegs
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | acarau
# Processing Record 12 of Set 4 | tupik
# Processing Record 13 of Set 4 | balabac
# Processing Record 14 of Set 4 | batagay
# Processing Record 15 of Set 4 | assiniboia
# Processing Record 16 of Set 4 | nishihara
# Processing Record 17 of Set 4 | hamilton
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | nanga eboko
# Processing Record 20 of Set 4 | tacna
# Processing Record 21 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | cumberland
# Processing Record 24 of Set 4 | paramonga
# Processing Record 25 of Set 4 | lebu
# Processing Record 26 of Set 4 | montepuez
# Processing Record 27 of Set 4 | arlit
# Processing Record 28 of Set 4 | honningsvag
# Processing Record 29 of Set 4 | baykit
# Processing Record 30 of Set 4 | novikovo
# Processing Record 31 of Set 4 | laguna
# Processing Record 32 of Set 4 | samarai
# Processing Record 33 of Set 4 | provideniya
# Processing Record 34 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 35 of Set 4 | novyy urengoy
# Processing Record 36 of Set 4 | andenes
# Processing Record 37 of Set 4 | jijiga
# Processing Record 38 of Set 4 | preston
# Processing Record 39 of Set 4 | ancud
# Processing Record 40 of Set 4 | kilindoni
# Processing Record 41 of Set 4 | lesnoy
# Processing Record 42 of Set 4 | monroe
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | tuatapere
# Processing Record 45 of Set 4 | geraldton
# Processing Record 46 of Set 4 | havre-saint-pierre
# Processing Record 47 of Set 4 | road town
# Processing Record 48 of Set 4 | sinnamary
# Processing Record 49 of Set 4 | portalegre
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | victoria
# Processing Record 3 of Set 5 | kahramanmaras
# Processing Record 4 of Set 5 | olinda
# Processing Record 5 of Set 5 | chany
# Processing Record 6 of Set 5 | sindor
# Processing Record 7 of Set 5 | mahebourg
# Processing Record 8 of Set 5 | oparino
# Processing Record 9 of Set 5 | nchelenge
# Processing Record 10 of Set 5 | amazar
# Processing Record 11 of Set 5 | hervey bay
# Processing Record 12 of Set 5 | ugoofaaru
# Processing Record 13 of Set 5 | hami
# Processing Record 14 of Set 5 | el wasta
# City not found. Skipping...
# Processing Record 15 of Set 5 | los llanos de aridane
# Processing Record 16 of Set 5 | trincomalee
# Processing Record 17 of Set 5 | orodara
# Processing Record 18 of Set 5 | bahia blanca
# Processing Record 19 of Set 5 | abaza
# Processing Record 20 of Set 5 | aguimes
# Processing Record 21 of Set 5 | christchurch
# Processing Record 22 of Set 5 | sabha
# Processing Record 23 of Set 5 | urucui
# Processing Record 24 of Set 5 | ossora
# Processing Record 25 of Set 5 | mizan teferi
# Processing Record 26 of Set 5 | aras
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | sabang
# Processing Record 29 of Set 5 | correntina
# Processing Record 30 of Set 5 | betare oya
# Processing Record 31 of Set 5 | pemangkat
# Processing Record 32 of Set 5 | coahuayana
# Processing Record 33 of Set 5 | comodoro rivadavia
# Processing Record 34 of Set 5 | normandin
# Processing Record 35 of Set 5 | lorengau
# Processing Record 36 of Set 5 | mimarsinan
# Processing Record 37 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 38 of Set 5 | faanui
# Processing Record 39 of Set 5 | ninotsminda
# Processing Record 40 of Set 5 | bara
# Processing Record 41 of Set 5 | sunderland
# Processing Record 42 of Set 5 | vanimo
# Processing Record 43 of Set 5 | ishinomaki
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | ayagoz
# Processing Record 46 of Set 5 | guane
# Processing Record 47 of Set 5 | qaanaaq
# Processing Record 48 of Set 5 | katsina
# Processing Record 49 of Set 5 | lagoa
# Processing Record 50 of Set 5 | palmer
# Processing Record 1 of Set 6 | ahipara
# Processing Record 2 of Set 6 | sur
# Processing Record 3 of Set 6 | nuuk
# Processing Record 4 of Set 6 | bilibino
# Processing Record 5 of Set 6 | verkhoyansk
# Processing Record 6 of Set 6 | tukrah
# Processing Record 7 of Set 6 | vila velha
# Processing Record 8 of Set 6 | shiraz
# Processing Record 9 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 6 | khani
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | nemuro
# Processing Record 13 of Set 6 | mananjary
# Processing Record 14 of Set 6 | coihaique
# Processing Record 15 of Set 6 | mitsamiouli
# Processing Record 16 of Set 6 | balkanabat
# Processing Record 17 of Set 6 | vallenar
# Processing Record 18 of Set 6 | saint-georges
# Processing Record 19 of Set 6 | linguere
# Processing Record 20 of Set 6 | cockburn town
# Processing Record 21 of Set 6 | yulara
# Processing Record 22 of Set 6 | winslow
# Processing Record 23 of Set 6 | ponta do sol
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | lata
# Processing Record 26 of Set 6 | omsukchan
# Processing Record 27 of Set 6 | jesus maria
# Processing Record 28 of Set 6 | presov
# Processing Record 29 of Set 6 | karaman
# Processing Record 30 of Set 6 | bartica
# Processing Record 31 of Set 6 | bambanglipuro
# Processing Record 32 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 6 | poltava
# Processing Record 34 of Set 6 | gimli
# Processing Record 35 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 36 of Set 6 | batemans bay
# Processing Record 37 of Set 6 | talnakh
# Processing Record 38 of Set 6 | rio pardo de minas
# Processing Record 39 of Set 6 | weligama
# Processing Record 40 of Set 6 | matara
# Processing Record 41 of Set 6 | derzhavinsk
# Processing Record 42 of Set 6 | mecca
# Processing Record 43 of Set 6 | benguela
# Processing Record 44 of Set 6 | acapulco
# Processing Record 45 of Set 6 | corralillo
# Processing Record 46 of Set 6 | tucurui
# Processing Record 47 of Set 6 | adjumani
# Processing Record 48 of Set 6 | xiangxiang
# Processing Record 49 of Set 6 | bend
# Processing Record 50 of Set 6 | korfez
# Processing Record 1 of Set 7 | airai
# Processing Record 2 of Set 7 | honiara
# Processing Record 3 of Set 7 | baraki barak
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 7 | zaysan
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | ostrovnoy
# Processing Record 9 of Set 7 | qafsah
# City not found. Skipping...
# Processing Record 10 of Set 7 | rundu
# Processing Record 11 of Set 7 | zwedru
# Processing Record 12 of Set 7 | broken hill
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | karangampel
# Processing Record 15 of Set 7 | lavrentiya
# Processing Record 16 of Set 7 | antalaha
# Processing Record 17 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 7 | husavik
# Processing Record 19 of Set 7 | ust-kut
# Processing Record 20 of Set 7 | ngunguru
# Processing Record 21 of Set 7 | pinega
# Processing Record 22 of Set 7 | inhambane
# Processing Record 23 of Set 7 | muzhi
# Processing Record 24 of Set 7 | long
# Processing Record 25 of Set 7 | kavaratti
# Processing Record 26 of Set 7 | klaksvik
# Processing Record 27 of Set 7 | labuhan
# Processing Record 28 of Set 7 | kamyshevatskaya
# Processing Record 29 of Set 7 | beloha
# Processing Record 30 of Set 7 | sisimiut
# Processing Record 31 of Set 7 | makasar
# Processing Record 32 of Set 7 | ixtapa
# Processing Record 33 of Set 7 | pierre
# Processing Record 34 of Set 7 | seryshevo
# Processing Record 35 of Set 7 | necocli
# Processing Record 36 of Set 7 | esperance
# Processing Record 37 of Set 7 | te anau
# Processing Record 38 of Set 7 | kjollefjord
# Processing Record 39 of Set 7 | port hardy
# Processing Record 40 of Set 7 | san fernando
# Processing Record 41 of Set 7 | lauf
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | yokadouma
# Processing Record 44 of Set 7 | paytug
# City not found. Skipping...
# Processing Record 45 of Set 7 | sorgun
# Processing Record 46 of Set 7 | laishevo
# Processing Record 47 of Set 7 | baghdad
# Processing Record 48 of Set 7 | aswan
# Processing Record 49 of Set 7 | kinanah
# City not found. Skipping...
# Processing Record 50 of Set 7 | ukiah
# Processing Record 1 of Set 8 | high level
# Processing Record 2 of Set 8 | vetovo
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | zaplyusye
# City not found. Skipping...
# Processing Record 5 of Set 8 | pinos
# Processing Record 6 of Set 8 | ust-tsilma
# Processing Record 7 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 8 of Set 8 | aljustrel
# Processing Record 9 of Set 8 | beringovskiy
# Processing Record 10 of Set 8 | bella union
# Processing Record 11 of Set 8 | mount gambier
# Processing Record 12 of Set 8 | mezen
# Processing Record 13 of Set 8 | terrace bay
# Processing Record 14 of Set 8 | onalaska
# Processing Record 15 of Set 8 | buzovna
# Processing Record 16 of Set 8 | champerico
# Processing Record 17 of Set 8 | hanmer springs
# Processing Record 18 of Set 8 | waiouru
# Processing Record 19 of Set 8 | vardo
# Processing Record 20 of Set 8 | terra santa
# Processing Record 21 of Set 8 | severodvinsk
# Processing Record 22 of Set 8 | aklavik
# Processing Record 23 of Set 8 | macia
# Processing Record 24 of Set 8 | avera
# Processing Record 25 of Set 8 | askiz
# Processing Record 26 of Set 8 | noumea
# Processing Record 27 of Set 8 | shimoda
# Processing Record 28 of Set 8 | salinopolis
# Processing Record 29 of Set 8 | urumqi
# Processing Record 30 of Set 8 | orthez
# Processing Record 31 of Set 8 | ryotsu
# Processing Record 32 of Set 8 | russell
# Processing Record 33 of Set 8 | albanel
# Processing Record 34 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 8 | uruacu
# Processing Record 36 of Set 8 | bisira
# Processing Record 37 of Set 8 | ulaangom
# Processing Record 38 of Set 8 | fort nelson
# Processing Record 39 of Set 8 | chara
# Processing Record 40 of Set 8 | mazamari
# Processing Record 41 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 8 | guelengdeng
# City not found. Skipping...
# Processing Record 43 of Set 8 | vostok
# Processing Record 44 of Set 8 | casino
# Processing Record 45 of Set 8 | esna
# Processing Record 46 of Set 8 | kempsey
# Processing Record 47 of Set 8 | kiunga
# Processing Record 48 of Set 8 | gornopravdinsk
# Processing Record 49 of Set 8 | evensk
# Processing Record 50 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 9 | alta floresta
# Processing Record 2 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 3 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 4 of Set 9 | tocopilla
# Processing Record 5 of Set 9 | teknaf
# Processing Record 6 of Set 9 | parsons
# Processing Record 7 of Set 9 | kutum
# Processing Record 8 of Set 9 | pangnirtung
# Processing Record 9 of Set 9 | lixourion
# Processing Record 10 of Set 9 | miragoane
# Processing Record 11 of Set 9 | nigran
# Processing Record 12 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 9 | benghazi
# Processing Record 14 of Set 9 | srednekolymsk
# Processing Record 15 of Set 9 | humaita
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | okmulgee
# Processing Record 18 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 9 | victor harbor
# Processing Record 20 of Set 9 | salekhard
# Processing Record 21 of Set 9 | souillac
# Processing Record 22 of Set 9 | salalah
# Processing Record 23 of Set 9 | jhajjar
# Processing Record 24 of Set 9 | kitaibaraki
# Processing Record 25 of Set 9 | ilulissat
# Processing Record 26 of Set 9 | bereda
# Processing Record 27 of Set 9 | gladstone
# Processing Record 28 of Set 9 | katherine
# Processing Record 29 of Set 9 | gizo
# Processing Record 30 of Set 9 | nouakchott
# Processing Record 31 of Set 9 | ardakan
# Processing Record 32 of Set 9 | kieta
# Processing Record 33 of Set 9 | pyapon
# Processing Record 34 of Set 9 | myanaung
# Processing Record 35 of Set 9 | bathsheba
# Processing Record 36 of Set 9 | green river
# Processing Record 37 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 9 | salvador
# Processing Record 39 of Set 9 | raton
# Processing Record 40 of Set 9 | tura
# Processing Record 41 of Set 9 | kulhudhuffushi
# Processing Record 42 of Set 9 | harper
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | price
# Processing Record 45 of Set 9 | san vicente
# Processing Record 46 of Set 9 | alyangula
# Processing Record 47 of Set 9 | isiro
# Processing Record 48 of Set 9 | williston
# Processing Record 49 of Set 9 | tokat
# Processing Record 50 of Set 9 | palembang
# Processing Record 1 of Set 10 | inongo
# Processing Record 2 of Set 10 | chicama
# Processing Record 3 of Set 10 | ongandjera
# Processing Record 4 of Set 10 | bad kissingen
# Processing Record 5 of Set 10 | jalu
# Processing Record 6 of Set 10 | whitehorse
# Processing Record 7 of Set 10 | haapu
# City not found. Skipping...
# Processing Record 8 of Set 10 | richards bay
# Processing Record 9 of Set 10 | saskylakh
# Processing Record 10 of Set 10 | faya
# Processing Record 11 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 13 of Set 10 | hasaki
# Processing Record 14 of Set 10 | qui nhon
# Processing Record 15 of Set 10 | pacific grove
# Processing Record 16 of Set 10 | tuktoyaktuk
# Processing Record 17 of Set 10 | kambove
# Processing Record 18 of Set 10 | carmen
# Processing Record 19 of Set 10 | alice springs
# Processing Record 20 of Set 10 | awbari
# Processing Record 21 of Set 10 | ardesen
# Processing Record 22 of Set 10 | copiapo
# Processing Record 23 of Set 10 | znamenskoye
# Processing Record 24 of Set 10 | valle del guamuez
# Processing Record 25 of Set 10 | edd
# Processing Record 26 of Set 10 | poyarkovo
# Processing Record 27 of Set 10 | vagur
# Processing Record 28 of Set 10 | marawi
# Processing Record 29 of Set 10 | antofagasta
# Processing Record 30 of Set 10 | gat
# Processing Record 31 of Set 10 | aldan
# Processing Record 32 of Set 10 | banda aceh
# Processing Record 33 of Set 10 | milas
# Processing Record 34 of Set 10 | jega
# Processing Record 35 of Set 10 | taoudenni
# Processing Record 36 of Set 10 | bilma
# Processing Record 37 of Set 10 | bac can
# City not found. Skipping...
# Processing Record 38 of Set 10 | shache
# Processing Record 39 of Set 10 | lompoc
# Processing Record 40 of Set 10 | teya
# Processing Record 41 of Set 10 | suntar
# Processing Record 42 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 10 | buncrana
# Processing Record 44 of Set 10 | hopkinsville
# Processing Record 45 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | shingu
# Processing Record 48 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 49 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 10 | mogadishu
# Processing Record 1 of Set 11 | santa rosa
# Processing Record 2 of Set 11 | iglesias
# Processing Record 3 of Set 11 | nadym
# Processing Record 4 of Set 11 | orlik
# Processing Record 5 of Set 11 | karratha
# Processing Record 6 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 11 | codrington
# Processing Record 8 of Set 11 | makhachkala
# Processing Record 9 of Set 11 | kaeo
# Processing Record 10 of Set 11 | cabo rojo
# Processing Record 11 of Set 11 | portland
# Processing Record 12 of Set 11 | voyvozh
# Processing Record 13 of Set 11 | pong
# Processing Record 14 of Set 11 | zolotinka
# City not found. Skipping...
# Processing Record 15 of Set 11 | nykoping
# Processing Record 16 of Set 11 | mareeba
# Processing Record 17 of Set 11 | liwale
# Processing Record 18 of Set 11 | ternovskaya
# Processing Record 19 of Set 11 | gamba
# Processing Record 20 of Set 11 | ketchikan
# Processing Record 21 of Set 11 | karpathos
# Processing Record 22 of Set 11 | conakry
# Processing Record 23 of Set 11 | churapcha
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | chernyshevskiy
# Processing Record 26 of Set 11 | afmadu
# City not found. Skipping...
# Processing Record 27 of Set 11 | dudinka
# Processing Record 28 of Set 11 | hongjiang
# Processing Record 29 of Set 11 | umm jarr
# City not found. Skipping...
# Processing Record 30 of Set 11 | sao joao da barra
# Processing Record 31 of Set 11 | kouqian
# Processing Record 32 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 33 of Set 11 | iroquois falls
# Processing Record 34 of Set 11 | malhargarh
# Processing Record 35 of Set 11 | orchard homes
# Processing Record 36 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 11 | sistranda
# Processing Record 38 of Set 11 | andijon
# Processing Record 39 of Set 11 | codajas
# Processing Record 40 of Set 11 | hirara
# Processing Record 41 of Set 11 | birjand
# Processing Record 42 of Set 11 | xinmin
# Processing Record 43 of Set 11 | marabba
# Processing Record 44 of Set 11 | nantucket
# Processing Record 45 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 11 | mehamn
# Processing Record 47 of Set 11 | zyryanka
# Processing Record 48 of Set 11 | teguldet
# Processing Record 49 of Set 11 | hopelchen
# Processing Record 50 of Set 11 | kloulklubed
# Processing Record 1 of Set 12 | businga
# Processing Record 2 of Set 12 | paredon
# Processing Record 3 of Set 12 | tarakan
# Processing Record 4 of Set 12 | huilong
# Processing Record 5 of Set 12 | winnemucca
# Processing Record 6 of Set 12 | khash
# Processing Record 7 of Set 12 | aktau
# Processing Record 8 of Set 12 | elko
# Processing Record 9 of Set 12 | montijo
# Processing Record 10 of Set 12 | kautokeino
# Processing Record 11 of Set 12 | qusar
# Processing Record 12 of Set 12 | sawtell
# Processing Record 13 of Set 12 | lahij
# Processing Record 14 of Set 12 | shaoyang
# Processing Record 15 of Set 12 | kurilsk
# Processing Record 16 of Set 12 | borama
# City not found. Skipping...
# Processing Record 17 of Set 12 | nenjiang
# Processing Record 18 of Set 12 | greensboro
# Processing Record 19 of Set 12 | culipapa
# City not found. Skipping...
# Processing Record 20 of Set 12 | kefamenanu
# Processing Record 21 of Set 12 | almaznyy
# Processing Record 22 of Set 12 | sa kaeo
# Processing Record 23 of Set 12 | thiruvananthapuram
# Processing Record 24 of Set 12 | tomatlan
# Processing Record 25 of Set 12 | ostersund
# Processing Record 26 of Set 12 | kandrian
# Processing Record 27 of Set 12 | killam
# Processing Record 28 of Set 12 | fairbanks
# Processing Record 29 of Set 12 | kidal
# Processing Record 30 of Set 12 | ocos
# Processing Record 31 of Set 12 | hinton
# Processing Record 32 of Set 12 | sao gabriel da cachoeira
# Processing Record 33 of Set 12 | coquimbo
# Processing Record 34 of Set 12 | cardston
# Processing Record 35 of Set 12 | odweyne
# Processing Record 36 of Set 12 | the valley
# Processing Record 37 of Set 12 | vrede
# Processing Record 38 of Set 12 | queanbeyan
# Processing Record 39 of Set 12 | hay river
# Processing Record 40 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 41 of Set 12 | volzhskiy
# Processing Record 42 of Set 12 | belmonte
# Processing Record 43 of Set 12 | la rioja
# Processing Record 44 of Set 12 | ulaanbaatar
# Processing Record 45 of Set 12 | rio grande
# Processing Record 46 of Set 12 | samagaltay
# Processing Record 47 of Set 12 | jardim
# Processing Record 48 of Set 12 | tahe
# Processing Record 49 of Set 12 | aksarka
# Processing Record 50 of Set 12 | kasangulu
# Processing Record 1 of Set 13 | uribia
# Processing Record 2 of Set 13 | morant bay
# Processing Record 3 of Set 13 | cecina
# Processing Record 4 of Set 13 | caravelas
# Processing Record 5 of Set 13 | taunggyi
# Processing Record 6 of Set 13 | mayo
# Processing Record 7 of Set 13 | oum hadjer
# Processing Record 8 of Set 13 | cururupu
# Processing Record 9 of Set 13 | blagoyevo
# Processing Record 10 of Set 13 | koksovyy
# Processing Record 11 of Set 13 | agsu
# City not found. Skipping...
# Processing Record 12 of Set 13 | kavieng
# Processing Record 13 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 13 | oudtshoorn
# Processing Record 15 of Set 13 | ust-nera
# Processing Record 16 of Set 13 | fort morgan
# Processing Record 17 of Set 13 | virovitica
# Processing Record 18 of Set 13 | nhulunbuy
# Processing Record 19 of Set 13 | harrisonburg
# Processing Record 20 of Set 13 | sabzevar
# Processing Record 21 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 22 of Set 13 | shubarkuduk
# Processing Record 23 of Set 13 | bognor regis
# Processing Record 24 of Set 13 | terme
# Processing Record 25 of Set 13 | manokwari
# Processing Record 26 of Set 13 | koboko
# Processing Record 27 of Set 13 | northam
# Processing Record 28 of Set 13 | serro
# Processing Record 29 of Set 13 | along
# Processing Record 30 of Set 13 | porto murtinho
# Processing Record 31 of Set 13 | mufulira
# Processing Record 32 of Set 13 | seymchan
# Processing Record 33 of Set 13 | bordighera
# Processing Record 34 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 35 of Set 13 | rosetta
# Processing Record 36 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 13 | lasa
# Processing Record 38 of Set 13 | reserva
# Processing Record 39 of Set 13 | eureka
# Processing Record 40 of Set 13 | kuala terengganu
# Processing Record 41 of Set 13 | marrakesh
# Processing Record 42 of Set 13 | porto walter
# Processing Record 43 of Set 13 | pilar
# Processing Record 44 of Set 13 | naron
# Processing Record 45 of Set 13 | panguipulli
# Processing Record 46 of Set 13 | takoradi
# Processing Record 47 of Set 13 | opuwo
# Processing Record 48 of Set 13 | piterka
# Processing Record 49 of Set 13 | libreville
# Processing Record 50 of Set 13 | shihezi
# Processing Record 1 of Set 14 | parauna
# Processing Record 2 of Set 14 | goderich
# Processing Record 3 of Set 14 | asilah
# Processing Record 4 of Set 14 | laela
# Processing Record 5 of Set 14 | leh
# Processing Record 6 of Set 14 | itupiranga
# Processing Record 7 of Set 14 | nanortalik
# Processing Record 8 of Set 14 | halmstad
# Processing Record 9 of Set 14 | gualeguay
# Processing Record 10 of Set 14 | wiarton
# Processing Record 11 of Set 14 | palaikastron
# Processing Record 12 of Set 14 | puno
# Processing Record 13 of Set 14 | katubao
# Processing Record 14 of Set 14 | kyren
# Processing Record 15 of Set 14 | kuytun
# Processing Record 16 of Set 14 | ao luk
# City not found. Skipping...
# Processing Record 17 of Set 14 | solnechnyy
# Processing Record 18 of Set 14 | luau
# Processing Record 19 of Set 14 | wanning
# Processing Record 20 of Set 14 | huangzhai
# Processing Record 21 of Set 14 | lodja
# Processing Record 22 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 14 | manzil jamil
# City not found. Skipping...
# Processing Record 24 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 14 | arrifes
# Processing Record 26 of Set 14 | nyurba
# Processing Record 27 of Set 14 | kruisfontein
# Processing Record 28 of Set 14 | tapaua
# City not found. Skipping...
# Processing Record 29 of Set 14 | xanlar
# Processing Record 30 of Set 14 | tulagi
# Processing Record 31 of Set 14 | matamoros
# Processing Record 32 of Set 14 | schwyz
# Processing Record 33 of Set 14 | henties bay
# Processing Record 34 of Set 14 | krasnyy chikoy
# Processing Record 35 of Set 14 | menongue
# Processing Record 36 of Set 14 | bubaque
# Processing Record 37 of Set 14 | najran
# Processing Record 38 of Set 14 | quipile
# Processing Record 39 of Set 14 | scarborough
# Processing Record 40 of Set 14 | mbarara
# Processing Record 41 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 14 | olafsvik
# Processing Record 43 of Set 14 | zlatoustovsk
# City not found. Skipping...
# Processing Record 44 of Set 14 | poum
# Processing Record 45 of Set 14 | aken
# Processing Record 46 of Set 14 | pokrovsk
# Processing Record 47 of Set 14 | okitipupa
# Processing Record 48 of Set 14 | iqaluit
# Processing Record 49 of Set 14 | tacuarembo
# Processing Record 50 of Set 14 | kifri
# Processing Record 1 of Set 15 | statesville
# Processing Record 2 of Set 15 | slave lake
# Processing Record 3 of Set 15 | salinas
# Processing Record 4 of Set 15 | uzumlu
# City not found. Skipping...
# Processing Record 5 of Set 15 | zhuhai
# Processing Record 6 of Set 15 | mtwara
# Processing Record 7 of Set 15 | claremore
# Processing Record 8 of Set 15 | marsa matruh
# Processing Record 9 of Set 15 | marathon
# Processing Record 10 of Set 15 | luanda
# Processing Record 11 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 12 of Set 15 | grindavik
# Processing Record 13 of Set 15 | boffa
# Processing Record 14 of Set 15 | hualmay
# Processing Record 15 of Set 15 | kisangani
# Processing Record 16 of Set 15 | sao jose dos pinhais
# Processing Record 17 of Set 15 | bandarbeyla
# Processing Record 18 of Set 15 | zasheyek
# Processing Record 19 of Set 15 | point fortin
# Processing Record 20 of Set 15 | discovery bay
# Processing Record 21 of Set 15 | santa cruz
# Processing Record 22 of Set 15 | caraballeda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Kahului  20.8947 -156.4700     84.22        69          40       13.80
# 1  East London -33.0153   27.9116     63.45        70         100       19.75
# 2      Rikitea -23.1203 -134.9692     74.26        78          56       13.06
# 3      Mataura -46.1927  168.8643     51.48        48          11        5.93
# 4       Albany  42.6001  -73.9662     72.73        82          97        7.49
#
#   Country                 Date Current Description
# 0      US  2021-09-15 02:11:44    scattered clouds
# 1      ZA  2021-09-15 02:11:45     overcast clouds
# 2      PF  2021-09-15 02:11:45       broken clouds
# 3      NZ  2021-09-15 02:11:45          few clouds
# 4      US  2021-09-15 02:07:31     overcast clouds

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
weather_data_df = weather_data_df[new_column_order]
weather_data_df
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0          Kahului      US  2021-09-15 02:11:44  20.8947 -156.4700     84.22
# 1      East London      ZA  2021-09-15 02:11:45 -33.0153   27.9116     63.45
# 2          Rikitea      PF  2021-09-15 02:11:45 -23.1203 -134.9692     74.26
# 3          Mataura      NZ  2021-09-15 02:11:45 -46.1927  168.8643     51.48
# 4           Albany      US  2021-09-15 02:07:31  42.6001  -73.9662     72.73
# ..             ...     ...                  ...      ...       ...       ...
# 647       Zasheyek      RU  2021-09-15 02:14:41  67.4066   32.5499     38.70
# 648   Point Fortin      TT  2021-09-15 02:14:42  10.1833  -61.6833     82.15
# 649  Discovery Bay      US  2021-09-15 02:14:42  37.9085 -121.6002     91.67
# 650     Santa Cruz      BO  2021-09-15 02:11:10 -17.8000  -63.1667     66.43
# 651    Caraballeda      VE  2021-09-15 02:14:42  10.6112  -66.8522     78.87
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          69          40       13.80    scattered clouds
# 1          70         100       19.75     overcast clouds
# 2          78          56       13.06       broken clouds
# 3          48          11        5.93          few clouds
# 4          82          97        7.49     overcast clouds
# ..        ...         ...         ...                 ...
# 647        87         100        9.71     overcast clouds
# 648        81           0       12.97           clear sky
# 649        27           1       13.80           clear sky
# 650        53          44       13.56    scattered clouds
# 651        83          75        5.75       broken clouds
#
# [652 rows x 10 columns]

# %%
# Save dataframe as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"

# %%
# Convert DataFrame to csv file
weather_data_df.to_csv(output_data_file, index_label="City_ID")
